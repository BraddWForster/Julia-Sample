# %%
using Plots
plot(sin, -3π, 3π, label = "sin(x)")

# %% [markdown]
# Euler formula found that
#
# $$ \exp(i \pi) = -1 $$

# %%
using LinearAlgebra
x = [1,2]
y = [3,4]
@show dot(x,y)
@show x ⋅ y
# Out:
# dot(x, y) = 11
# x ⋅ y = 11
# 11
